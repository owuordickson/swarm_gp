# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

# Read all results from txt files


aco_path = "./ACO/"
aco_files = [f for f in listdir(aco_path) if isfile(join(aco_path, f))]

ga_path = "./GA/"
ga_files = [f for f in listdir(ga_path) if isfile(join(ga_path, f))]

pso_path = "./PSO/"
pso_files = [f for f in listdir(pso_path) if isfile(join(pso_path, f))]

pls_path = "./PLS/"
pls_files = [f for f in listdir(pls_path) if isfile(join(pls_path, f))]

prs_path = "./PRS/"
prs_files = [f for f in listdir(prs_path) if isfile(join(prs_path, f))]





# Ant Colony Optimization - Data Frame
column_names = ["Data-set", "Size", "Algorithm", "Support", "Run-time", "Memory", "Pattern-count", "Max-iteration", "Iterations", "E-factor"]
df_aco = pd.DataFrame(columns = column_names)

for file in aco_files:
    f_path = join(aco_path,file)
    # res = pd.read_csv(f_path, sep = ': ', header=None, engine='python', nrows=10)
    res = pd.read_csv(f_path, names=["A","B"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size

    evp = float(res['B'][5]) # evaporation factor

    sup = float(res['B'][6]) # minimum support
    pat = float(res['B'][8]) # patterns
    mit = int(res['B'][9]) # maximum iteraction count
    
    # Fetch best-cost iteration values
    its = [0] * mit
    it_st = res.loc[res['B'] == ' Best Cost'].index[0] + 1 # iterations
    for i in range(mit):
        it = i + it_st
        its[i] = float(res['B'][it]) # cost
    
    if att == 11:
        col = "HCV"
    else:
        col = ""
                    
    df_aco = df_aco.append({"Data-set": col, "Size": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "Max-iteration":mit, "Iterations":its, "E-factor": evp}, ignore_index=True)

    
    

# -------------------------------------------------------------------------------------
# Genetic Algorithm - Data Frame
column_names = ["Data-set", "Size", "Algorithm", "Support", "Run-time", "Memory", "Pattern-count", "Max-iteration", "Iterations", "N-pop", "PC"]
df_ga = pd.DataFrame(columns = column_names)

for file in ga_files:
    f_path = join(ga_path,file)
    res = pd.read_csv(f_path, names=["A","B"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size

    pop = float(res['B'][5]) # population size
    pc = float(res['B'][6]) # population size


    sup = float(res['B'][7]) # minimum support
    pat = float(res['B'][9]) # patterns
    mit = int(res['B'][10]) # maximum iteraction count
    
    # Fetch best-cost iteration values
    its = [0] * mit
    it_st = res.loc[res['B'] == ' Best Cost'].index[0] + 1 # iterations
    for i in range(mit):
        it = i + it_st
        its[i] = float(res['B'][it]) # cost
    
    if att == 11:
        col = "HCV"
    else:
        col = ""
        
    df_ga = df_ga.append({"Data-set": col, "Size": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "Max-iteration":mit, "Iterations":its, "N-pop": pop, "PC": pc}, ignore_index=True)

    
    
    
    


# -------------------------------------------------------------------------------------
# Particle Swarm Optimization - Data Frame
column_names = ["Data-set", "Size", "Algorithm", "Support", "Run-time", "Memory", "Pattern-count", "Max-iteration", "Iterations", "N-particle", "Velocity", "C1", "C2"]
df_pso = pd.DataFrame(columns = column_names)

for file in pso_files:
    f_path = join(pso_path,file)
    res = pd.read_csv(f_path, names=["A","B"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size

    vel = float(res['B'][5]) # velocity
    c1 = float(res['B'][6]) # personal coefficient
    c2 = float(res['B'][7]) # global coefficient
    npat = float(res['B'][8]) # particle count

    sup = float(res['B'][9]) # minimum support
    pat = float(res['B'][11]) # patterns
    mit = int(res['B'][12]) # maximum iteraction count
    
    # Fetch best-cost iteration values
    its = [0] * mit
    it_st = res.loc[res['B'] == ' Best Cost'].index[0] + 1 # iterations
    for i in range(mit):
        it = i + it_st
        its[i] = float(res['B'][it]) # cost
    
    if att == 11:
        col = "HCV"
    else:
        col = ""
        
    df_pso = df_pso.append({"Data-set": col, "Size": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "Max-iteration":mit, "Iterations":its, "N-particle": npat, "Velocity": vel, "C1": c1, "C2": c2}, ignore_index=True)

    

    
    
# -------------------------------------------------------------------------------------
# Pure Local Search - Data Frame
column_names = ["Data-set", "Size", "Algorithm", "Support", "Run-time", "Memory", "Pattern-count", "Max-iteration", "Iterations", "Step-size"]
df_pls = pd.DataFrame(columns = column_names)

for file in pls_files:
    f_path = join(pls_path,file)
    # res = pd.read_csv(f_path, sep = ': ', header=None, engine='python', nrows=10)
    res = pd.read_csv(f_path, names=["A","B"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size

    stp = float(res['B'][5]) # step size

    sup = float(res['B'][6]) # minimum support
    pat = float(res['B'][8]) # patterns
    mit = int(res['B'][9]) # maximum iteraction count
    
    # Fetch best-cost iteration values
    its = [0] * mit
    it_st = res.loc[res['B'] == ' Best Cost'].index[0] + 1 # iterations
    for i in range(mit):
        it = i + it_st
        its[i] = float(res['B'][it]) # cost
    
    if att == 11:
        col = "HCV"
    else:
        col = ""
                    
    df_pls = df_pls.append({"Data-set": col, "Size": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "Max-iteration":mit, "Iterations":its, "Step-size": stp}, ignore_index=True)

    
    
    

# -------------------------------------------------------------------------------------
# Pure Local Search - Data Frame
column_names = ["Data-set", "Size", "Algorithm", "Support", "Run-time", "Memory", "Pattern-count", "Max-iteration", "Iterations"]
df_prs = pd.DataFrame(columns = column_names)

for file in prs_files:
    f_path = join(prs_path,file)
    # res = pd.read_csv(f_path, sep = ': ', header=None, engine='python', nrows=10)
    res = pd.read_csv(f_path, names=["A","B"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size

    sup = float(res['B'][5]) # minimum support
    pat = float(res['B'][7]) # patterns
    mit = int(res['B'][8]) # maximum iteraction count
    
    # Fetch best-cost iteration values
    its = [0] * mit
    it_st = res.loc[res['B'] == ' Best Cost'].index[0] + 1 # iterations
    for i in range(mit):
        it = i + it_st
        its[i] = float(res['B'][it]) # cost
    
    if att == 11:
        col = "HCV"
    else:
        col = ""
                    
    df_prs = df_prs.append({"Data-set": col, "Size": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "Max-iteration":mit, "Iterations":its}, ignore_index=True)

# %%
df_aco1 = df_aco[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory', 'E-factor']]
df_aco1 = df_aco1.groupby(["Algorithm", "E-factor", "Data-set"]).describe(percentiles=[])
df_aco1
# Out:
#                                      Pattern-count                             \
#                                              count       mean       std   min
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v4.0) 0.01     HCV                3.0  34.666667  4.509250  30.0
#                    0.05     HCV                3.0  30.000000  2.645751  27.0
#                    0.10     HCV                3.0  26.666667  0.577350  26.0
#                    0.50     HCV                3.0  23.333333  2.081666  21.0
#
#                                                  Run-time                      \
#                                        50%   max    count      mean       std
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v4.0) 0.01     HCV       35.0  39.0      3.0  4.127333  0.151071
#                    0.05     HCV       31.0  32.0      3.0  3.994333  0.115768
#                    0.10     HCV       27.0  27.0      3.0  3.887667  0.042829
#                    0.50     HCV       24.0  25.0      3.0  4.510667  1.133157
#
#                                                           Memory              \
#                                         min    50%    max  count        mean
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v4.0) 0.01     HCV       3.979  4.122  4.281    3.0  215.000000
#                    0.05     HCV       3.926  3.929  4.128    3.0  214.666667
#                    0.10     HCV       3.860  3.866  3.937    3.0  214.000000
#                    0.50     HCV       3.750  3.969  5.813    3.0  214.000000
#
#
#                                           std    min    50%    max
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v4.0) 0.01     HCV       0.00000  215.0  215.0  215.0
#                    0.05     HCV       0.57735  214.0  215.0  215.0
#                    0.10     HCV       0.00000  214.0  214.0  214.0
#                    0.50     HCV       0.00000  214.0  214.0  214.0

# %%
df_ga1 = df_ga[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory', 'N-pop', 'PC']]
df_ga1 = df_ga1.groupby(["Algorithm", "N-pop", "PC", "Data-set"]).describe(percentiles=[])
df_ga1
# Out:
#                                       Pattern-count                           \
#                                               count mean       std  min  50%
# Algorithm         N-pop PC   Data-set
#  GA-GRAANK (v2.0) 5.0   0.01 HCV                3.0  1.0  0.000000  1.0  1.0
#                         0.05 HCV                3.0  1.0  0.000000  1.0  1.0
#                         0.10 HCV                3.0  1.0  0.000000  1.0  1.0
#                         0.50 HCV                3.0  2.0  1.732051  1.0  1.0
#
#                                            Run-time                      \
#                                        max    count      mean       std
# Algorithm         N-pop PC   Data-set
#  GA-GRAANK (v2.0) 5.0   0.01 HCV       1.0      3.0  0.435000  0.013115
#                         0.05 HCV       1.0      3.0  0.489000  0.049930
#                         0.10 HCV       1.0      3.0  0.421333  0.031501
#                         0.50 HCV       4.0      3.0  0.708000  0.085610
#
#                                                            Memory             \
#                                          min    50%    max  count       mean
# Algorithm         N-pop PC   Data-set
#  GA-GRAANK (v2.0) 5.0   0.01 HCV       0.421  0.437  0.447    3.0  81.633333
#                         0.05 HCV       0.453  0.468  0.546    3.0  82.066667
#                         0.10 HCV       0.390  0.421  0.453    3.0  81.633333
#                         0.50 HCV       0.625  0.703  0.796    3.0  87.200000
#
#
#                                             std   min   50%   max
# Algorithm         N-pop PC   Data-set
#  GA-GRAANK (v2.0) 5.0   0.01 HCV       0.321455  81.4  81.5  82.0
#                         0.05 HCV       0.208167  81.9  82.0  82.3
#                         0.10 HCV       0.416333  81.3  81.5  82.1
#                         0.50 HCV       1.743560  86.0  86.4  89.2

# %%
df_pso1 = df_pso[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory', 'N-particle', 'Velocity', 'C1', 'C2']]
df_pso1 = df_pso1.groupby(["Algorithm", "N-particle", "C1", "C2", "Velocity", "Data-set"]).describe(percentiles=[])
df_pso1
# Out:
#                                                         Pattern-count  \
#                                                                 count
# Algorithm          N-particle C1  C2  Velocity Data-set
#  PSO-GRAANK (v2.0) 5.0        0.1 0.9 0.01     HCV                3.0
#                                       0.05     HCV                3.0
#                                       0.10     HCV                3.0
#                                       0.50     HCV                3.0
#
#                                                                              \
#                                                              mean       std
# Algorithm          N-particle C1  C2  Velocity Data-set
#  PSO-GRAANK (v2.0) 5.0        0.1 0.9 0.01     HCV       2.000000  1.000000
#                                       0.05     HCV       2.333333  0.577350
#                                       0.10     HCV       3.000000  1.000000
#                                       0.50     HCV       1.666667  1.154701
#
#                                                                         \
#                                                          min  50%  max
# Algorithm          N-particle C1  C2  Velocity Data-set
#  PSO-GRAANK (v2.0) 5.0        0.1 0.9 0.01     HCV       1.0  2.0  3.0
#                                       0.05     HCV       2.0  2.0  3.0
#                                       0.10     HCV       2.0  3.0  4.0
#                                       0.50     HCV       1.0  1.0  3.0
#
#                                                         Run-time            \
#                                                            count      mean
# Algorithm          N-particle C1  C2  Velocity Data-set
#  PSO-GRAANK (v2.0) 5.0        0.1 0.9 0.01     HCV           3.0  1.051333
#                                       0.05     HCV           3.0  1.072667
#                                       0.10     HCV           3.0  0.911000
#                                       0.50     HCV           3.0  1.093000
#
#                                                                           \
#                                                               std    min
# Algorithm          N-particle C1  C2  Velocity Data-set
#  PSO-GRAANK (v2.0) 5.0        0.1 0.9 0.01     HCV       0.164065  0.890
#                                       0.05     HCV       0.088342  1.000
#                                       0.10     HCV       0.036373  0.890
#                                       0.50     HCV       0.121445  0.953
#
#                                                                       Memory  \
#                                                            50%    max  count
# Algorithm          N-particle C1  C2  Velocity Data-set
#  PSO-GRAANK (v2.0) 5.0        0.1 0.9 0.01     HCV       1.046  1.218    3.0
#                                       0.05     HCV       1.047  1.171    3.0
#                                       0.10     HCV       0.890  0.953    3.0
#                                       0.50     HCV       1.156  1.170    3.0
#
#                                                                               \
#                                                               mean       std
# Algorithm          N-particle C1  C2  Velocity Data-set
#  PSO-GRAANK (v2.0) 5.0        0.1 0.9 0.01     HCV       82.300000  0.700000
#                                       0.05     HCV       82.733333  0.503322
#                                       0.10     HCV       83.666667  1.457166
#                                       0.50     HCV       82.233333  1.011599
#
#
#                                                           min   50%   max
# Algorithm          N-particle C1  C2  Velocity Data-set
#  PSO-GRAANK (v2.0) 5.0        0.1 0.9 0.01     HCV       81.6  82.3  83.0
#                                       0.05     HCV       82.2  82.8  83.2
#                                       0.10     HCV       82.3  83.5  85.2
#                                       0.50     HCV       81.6  81.7  83.4

# %%
df_pls1 = df_pls[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory', 'Step-size']]
df_pls1 = df_pls1.groupby(["Algorithm", "Step-size", "Data-set"]).describe(percentiles=[])
df_pls1
# Out:
#                                       Pattern-count                           \
#                                               count      mean       std  min
# Algorithm          Step-size Data-set
#  PLS-GRAANK (v1.0) 0.01      HCV                3.0  3.000000  2.000000  1.0
#                    0.05      HCV                3.0  3.333333  0.577350  3.0
#                    0.10      HCV                3.0  2.333333  1.154701  1.0
#                    0.50      HCV                3.0  1.666667  0.577350  1.0
#
#                                                 Run-time                      \
#                                        50%  max    count      mean       std
# Algorithm          Step-size Data-set
#  PLS-GRAANK (v1.0) 0.01      HCV       3.0  5.0      3.0  0.598667  0.080027
#                    0.05      HCV       3.0  4.0      3.0  0.577667  0.027135
#                    0.10      HCV       3.0  3.0      3.0  0.598333  0.039273
#                    0.50      HCV       2.0  2.0      3.0  1.182000  1.073991
#
#                                                            Memory             \
#                                          min    50%    max  count       mean
# Algorithm          Step-size Data-set
#  PLS-GRAANK (v1.0) 0.01      HCV       0.531  0.578  0.687    3.0  80.100000
#                    0.05      HCV       0.562  0.562  0.609    3.0  81.533333
#                    0.10      HCV       0.562  0.593  0.640    3.0  80.300000
#                    0.50      HCV       0.546  0.578  2.422    3.0  79.633333
#
#
#                                             std   min   50%   max
# Algorithm          Step-size Data-set
#  PLS-GRAANK (v1.0) 0.01      HCV       3.122499  76.6  81.1  82.6
#                    0.05      HCV       0.757188  81.0  81.2  82.4
#                    0.10      HCV       2.740438  77.2  81.3  82.4
#                    0.50      HCV       0.642910  78.9  79.9  80.1

# %%
df_prs1 = df_prs[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory']]
df_prs1 = df_prs1.groupby(["Algorithm", "Data-set"]).describe(percentiles=[])
df_prs1
# Out:
#                             Pattern-count                          Run-time  \
#                                     count mean  std  min  50%  max    count
# Algorithm          Data-set
#  PRS-GRAANK (v1.0) HCV                3.0  3.0  0.0  3.0  3.0  3.0      3.0
#
#                                                                      Memory  \
#                                  mean       std    min    50%    max  count
# Algorithm          Data-set
#  PRS-GRAANK (v1.0) HCV       0.566333  0.028729  0.545  0.555  0.599    3.0
#
#
#                                   mean       std   min   50%   max
# Algorithm          Data-set
#  PRS-GRAANK (v1.0) HCV       80.566667  0.321455  80.2  80.7  80.8

# %%
# Combining the results
frames = [df_aco, df_ga, df_pso, df_pls, df_prs]
df_res = pd.concat(frames)

# Only include these columns
df_res2 = df_res[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory']]  #, 'E-factor', 'N-pop', 'N-particle', 'C1', 'C2']]

df = df_res2.groupby(['Algorithm', 'Data-set'])#.describe(percentiles=[])
df2 = pd.concat([df.min(), df.mean(), df.max(), df.std()], keys=['min', 'mean', 'max', 'std'], axis=1)
# df2.filter(like="Run-time")
df2.columns = df2.columns.swaplevel(0, 1)
df2.sort_index(axis=1, level=0, inplace=True, ascending=False)
df2.round(3)
# Out:
#                             Run-time                      Pattern-count        \
#                                  std    min   mean    max           std   min
# Algorithm          Data-set
#  ACO-GRAANK (v4.0) HCV         0.549  3.750  4.130  5.813         4.997  21.0
#  GA-GRAANK (v2.0)  HCV         0.154  0.390  0.543  0.796         0.855   1.0
#  PLS-GRAANK (v1.0) HCV         0.532  0.531  0.739  2.422         1.240   1.0
#  PRS-GRAANK (v1.0) HCV         0.029  0.545  0.566  0.599         0.000   3.0
#  PSO-GRAANK (v2.0) HCV         0.122  0.890  1.032  1.218         0.965   1.0
#
#                                           Memory
#                                mean   max    std    min     mean    max
# Algorithm          Data-set
#  ACO-GRAANK (v4.0) HCV       28.667  39.0  0.515  214.0  214.417  215.0
#  GA-GRAANK (v2.0)  HCV        1.308   4.0  2.651   81.3   83.377   89.2
#  PLS-GRAANK (v1.0) HCV        2.583   5.0  1.964   76.6   80.392   82.6
#  PRS-GRAANK (v1.0) HCV        3.000   3.0  0.321   80.2   80.567   80.8
#  PSO-GRAANK (v2.0) HCV        2.250   4.0  1.032   81.6   82.733   85.2

# %%
import matplotlib.pyplot as plt

data_sets = ['HCV']

for ds in data_sets:
    df1 = df_aco.loc[df_aco['Data-set'] == ds]
    
    e_fs = [0.01, 0.05, 0.1, 0.5]
    
    for e in e_fs:
        df2 = df1.loc[df1['E-factor'] == e]
    
        fig = plt.figure(figsize=(40,5))
        #fig = plt.figure()
        #axes = fig.subplots(nrows=1, ncols=4)
        i = 1
        for index,row in df2.iterrows():
            # Results
            plt.subplot(1, 3, i)
            plt.plot(row['Iterations'])
            plt.semilogy(row['Iterations'])
            plt.xlim(0, row['Max-iteration'])
            plt.xlabel('Iterations')
            plt.ylabel('Best Cost')
            #plt.title('ACO, Dataset: ' + ds)
            plt.grid(True)
            i += 1

        fig.suptitle('Algorithm: ACO-GRAANK; E.factor: ' + str(e) + '; Dataset: ' + ds, fontsize=32)
        plt.show()

# %%
for ds in data_sets:
    df1 = df_ga.loc[df_ga['Data-set'] == ds]
    pcs = [0.01, 0.05, 0.1, 0.5]
    
    for pc in pcs:
        df2 = df1.loc[df1['PC'] == pc]
    
        fig = plt.figure(figsize=(40,5))
        #fig = plt.figure()
        #axes = fig.subplots(nrows=1, ncols=4)
        i = 1
        for index,row in df2.iterrows():
            # Results
            plt.subplot(1, 4, i)
            plt.plot(row['Iterations'])
            plt.semilogy(row['Iterations'])
            plt.xlim(0, row['Max-iteration'])
            plt.xlabel('Iterations')
            plt.ylabel('Best Cost')
            #plt.title('ACO, Dataset: ' + ds)
            plt.grid(True)
            i += 1

        fig.suptitle('Algorithm: GA; Npop: ' + str(row['N-pop']) + '; PC: ' + str(pc) + '; Dataset: ' + ds, fontsize=32)
        plt.show()

# %%
for ds in data_sets:
    df1 = df_pls.loc[df_pls['Data-set'] == ds]
    stps = [0.01, 0.05, 0.1, 0.5]
    
    for stp in stps:
        df2 = df1.loc[df1['Step-size'] == stp]
    
        fig = plt.figure(figsize=(40,5))
        #fig = plt.figure()
        #axes = fig.subplots(nrows=1, ncols=4)
        i = 1
        for index,row in df2.iterrows():
            # Results
            plt.subplot(1, 4, i)
            plt.plot(row['Iterations'])
            plt.semilogy(row['Iterations'])
            plt.xlim(0, row['Max-iteration'])
            plt.xlabel('Iterations')
            plt.ylabel('Best Cost')
            #plt.title('ACO, Dataset: ' + ds)
            plt.grid(True)
            i += 1

        fig.suptitle('Algorithm: PLA; Step-size: ' + str(row['Step-size']) + '; Dataset: ' + ds, fontsize=32)
        plt.show()

# %%
for ds in data_sets:
    df1 = df_prs.loc[df_pls['Data-set'] == ds]
    # stps = [0.01, 0.05, 0.1, 0.5]
    
    # for stp in stps:
    #    df2 = df1.loc[df1['Step-size'] == stp]
    
    fig = plt.figure(figsize=(40,5))

    i = 1
    for index,row in df1.iterrows():
        # Results
        plt.subplot(1, 3, i)
        plt.plot(row['Iterations'])
        plt.semilogy(row['Iterations'])
        plt.xlim(0, row['Max-iteration'])
        plt.xlabel('Iterations')
        plt.ylabel('Best Cost')
        #plt.title('ACO, Dataset: ' + ds)
        plt.grid(True)
        i += 1

    fig.suptitle('Algorithm: PRA; ' + '; Dataset: ' + ds, fontsize=32)
    plt.show()
